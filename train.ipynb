# %%
# drug 데이터를 불러옵니다.
import pandas as pd

data = pd.read_csv('C:\\sw\\first_project\\hand_landmarks.csv')
data
# Out:
#           Timestamp  UserInput  Left_Landmark_0_X  Left_Landmark_1_X  \
# 0      2.408100e+11          0                  0          -0.087101
# 1      2.408100e+11          0                  0          -0.090673
# 2      2.408100e+11          0                  0          -0.093260
# 3      2.408100e+11          0                  0          -0.093871
# 4      2.408100e+11          0                  0          -0.094523
# ...             ...        ...                ...                ...
# 25732  2.408100e+11         27                  0          -0.034690
# 25733  2.408100e+11         27                  0          -0.031339
# 25734  2.408100e+11         27                  0          -0.037350
# 25735  2.408100e+11         27                  0          -0.037510
# 25736  2.408100e+11         27                  0          -0.036312
#
#        Left_Landmark_2_X  Left_Landmark_3_X  Left_Landmark_4_X  \
# 0              -0.165992          -0.232231          -0.290516
# 1              -0.169900          -0.236820          -0.298699
# 2              -0.173344          -0.241023          -0.303851
# 3              -0.173500          -0.241609          -0.305493
# 4              -0.175004          -0.243528          -0.307717
# ...                  ...                ...                ...
# 25732          -0.060718          -0.073774          -0.070635
# 25733          -0.057342          -0.073066          -0.080513
# 25734          -0.068002          -0.085258          -0.089748
# 25735          -0.063495          -0.079920          -0.093409
# 25736          -0.063002          -0.079791          -0.092804
#
#        Left_Landmark_5_X  Left_Landmark_6_X  Left_Landmark_7_X  ...  \
# 0              -0.158022          -0.144542          -0.137421  ...
# 1              -0.166345          -0.150809          -0.143055  ...
# 2              -0.173472          -0.158633          -0.149355  ...
# 3              -0.172891          -0.159785          -0.149359  ...
# 4              -0.174192          -0.160174          -0.149595  ...
# ...                  ...                ...                ...  ...
# 25732          -0.046587          -0.076383          -0.077455  ...
# 25733          -0.048726          -0.078070          -0.079228  ...
# 25734          -0.056137          -0.089122          -0.089611  ...
# 25735          -0.048077          -0.089711          -0.095376  ...
# 25736          -0.042866          -0.087831          -0.099575  ...
#
#        Unnamed: 118  Unnamed: 119  Unnamed: 120  Unnamed: 121  Unnamed: 122  \
# 0               NaN           NaN           NaN           NaN           NaN
# 1               NaN           NaN           NaN           NaN           NaN
# 2               NaN           NaN           NaN           NaN           NaN
# 3               NaN           NaN           NaN           NaN           NaN
# 4               NaN           NaN           NaN           NaN           NaN
# ...             ...           ...           ...           ...           ...
# 25732           NaN           NaN           NaN           NaN           NaN
# 25733           NaN           NaN           NaN           NaN           NaN
# 25734           NaN           NaN           NaN           NaN           NaN
# 25735           NaN           NaN           NaN           NaN           NaN
# 25736           NaN           NaN           NaN           NaN           NaN
#
#        Unnamed: 123  Unnamed: 124  Unnamed: 125  Unnamed: 126  Unnamed: 127
# 0               NaN           NaN           NaN           NaN           NaN
# 1               NaN           NaN           NaN           NaN           NaN
# 2               NaN           NaN           NaN           NaN           NaN
# 3               NaN           NaN           NaN           NaN           NaN
# 4               NaN           NaN           NaN           NaN           NaN
# ...             ...           ...           ...           ...           ...
# 25732           NaN           NaN           NaN           NaN           NaN
# 25733           NaN           NaN           NaN           NaN           NaN
# 25734           NaN           NaN           NaN           NaN           NaN
# 25735           NaN           NaN           NaN           NaN           NaN
# 25736           NaN           NaN           NaN           NaN           NaN
#
# [25737 rows x 128 columns]

# %%
#레이블 선택
data_label = data.iloc[:, 1]
data_label
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 25732    27
# 25733    27
# 25734    27
# 25735    27
# 25736    27
# Name: UserInput, Length: 25737, dtype: int64

# %%
# drug 데이터에서 특징 값을 선택합니다.
# 약물 처방에 필요한 데이터를 선택하고, 불필요한 것은 삭제하거나 선택하지 않습니다.
data_data = data.iloc[:,:65] #행전체 4열까지
data_data
# Out:
#           Timestamp  UserInput  Left_Landmark_0_X  Left_Landmark_1_X  \
# 0      2.408100e+11          0                  0          -0.087101
# 1      2.408100e+11          0                  0          -0.090673
# 2      2.408100e+11          0                  0          -0.093260
# 3      2.408100e+11          0                  0          -0.093871
# 4      2.408100e+11          0                  0          -0.094523
# ...             ...        ...                ...                ...
# 25732  2.408100e+11         27                  0          -0.034690
# 25733  2.408100e+11         27                  0          -0.031339
# 25734  2.408100e+11         27                  0          -0.037350
# 25735  2.408100e+11         27                  0          -0.037510
# 25736  2.408100e+11         27                  0          -0.036312
#
#        Left_Landmark_2_X  Left_Landmark_3_X  Left_Landmark_4_X  \
# 0              -0.165992          -0.232231          -0.290516
# 1              -0.169900          -0.236820          -0.298699
# 2              -0.173344          -0.241023          -0.303851
# 3              -0.173500          -0.241609          -0.305493
# 4              -0.175004          -0.243528          -0.307717
# ...                  ...                ...                ...
# 25732          -0.060718          -0.073774          -0.070635
# 25733          -0.057342          -0.073066          -0.080513
# 25734          -0.068002          -0.085258          -0.089748
# 25735          -0.063495          -0.079920          -0.093409
# 25736          -0.063002          -0.079791          -0.092804
#
#        Left_Landmark_5_X  Left_Landmark_6_X  Left_Landmark_7_X  ...  \
# 0              -0.158022          -0.144542          -0.137421  ...
# 1              -0.166345          -0.150809          -0.143055  ...
# 2              -0.173472          -0.158633          -0.149355  ...
# 3              -0.172891          -0.159785          -0.149359  ...
# 4              -0.174192          -0.160174          -0.149595  ...
# ...                  ...                ...                ...  ...
# 25732          -0.046587          -0.076383          -0.077455  ...
# 25733          -0.048726          -0.078070          -0.079228  ...
# 25734          -0.056137          -0.089122          -0.089611  ...
# 25735          -0.048077          -0.089711          -0.095376  ...
# 25736          -0.042866          -0.087831          -0.099575  ...
#
#        Left_Landmark_11_Z  Left_Landmark_12_Z  Left_Landmark_13_Z  \
# 0               -0.088079           -0.068430           -0.113075
# 1               -0.073133           -0.054656           -0.100992
# 2               -0.062117           -0.042642           -0.095733
# 3               -0.067940           -0.047769           -0.101409
# 4               -0.072087           -0.056052           -0.099068
# ...                   ...                 ...                 ...
# 25732           -0.100366           -0.104087           -0.067428
# 25733           -0.094287           -0.096209           -0.068137
# 25734           -0.061184           -0.063470           -0.045842
# 25735           -0.051125           -0.047047           -0.051391
# 25736           -0.055794           -0.051428           -0.054872
#
#        Left_Landmark_14_Z  Left_Landmark_15_Z  Left_Landmark_16_Z  \
# 0               -0.112787           -0.068123           -0.041737
# 1               -0.096030           -0.053441           -0.029273
# 2               -0.089297           -0.044041           -0.017620
# 3               -0.096202           -0.047554           -0.018662
# 4               -0.092847           -0.045073           -0.017122
# ...                   ...                 ...                 ...
# 25732           -0.096278           -0.094504           -0.090132
# 25733           -0.096182           -0.092317           -0.087028
# 25734           -0.062083           -0.060357           -0.058966
# 25735           -0.064958           -0.053408           -0.044834
# 25736           -0.068271           -0.056854           -0.048721
#
#        Left_Landmark_17_Z  Left_Landmark_18_Z  Left_Landmark_19_Z  \
# 0               -0.119446           -0.115010           -0.082669
# 1               -0.107171           -0.098885           -0.067399
# 2               -0.104719           -0.093794           -0.059803
# 3               -0.111001           -0.100828           -0.064649
# 4               -0.109311           -0.097266           -0.060903
# ...                   ...                 ...                 ...
# 25732           -0.084168           -0.106402           -0.110697
# 25733           -0.084511           -0.107315           -0.110272
# 25734           -0.057078           -0.067040           -0.065506
# 25735           -0.066490           -0.073012           -0.064376
# 25736           -0.068614           -0.074980           -0.066628
#
#        Left_Landmark_20_Z
# 0               -0.061357
# 1               -0.047344
# 2               -0.037781
# 3               -0.040752
# 4               -0.037373
# ...                   ...
# 25732           -0.112137
# 25733           -0.110554
# 25734           -0.064329
# 25735           -0.057893
# 25736           -0.060511
#
# [25737 rows x 65 columns]

# %%
# 데이터를 학습 데이터와 검증 데이터로 분할합니다.
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data_data, data_label, test_size=0.2)

# %%
# KNN 모델을 생성하여 학습

from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5, n_jobs=-1) #n_naighbors = k값 지정
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_jobs=-1)

# %%
#KNN 모델 예측 정확도
from sklearn.metrics import accuracy_score
y_pred = knn.predict(X_test)

print('예측 정확도:%f' %(accuracy_score(y_test,y_pred)))
# Out:
# 예측 정확도:0.027001

# %%
# 모델을 파일로 저장
import joblib

model_filename = 'knn_model.pkl'
joblib.dump(knn, model_filename)

print(f"모델이 '{model_filename}' 파일로 저장되었습니다.")
# Out:
# 모델이 'knn_model.pkl' 파일로 저장되었습니다.

# %%
# 로지스틱 회귀 모델을 생성하고 학습합니다.
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression()
lr_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# 예측한 레이블과 실제 레이블이 얼마나 유사한지 정확도를 계산합니다.
lr_acc = accuracy_score(y_pred, y_test)
print("accuracy: {}".format(lr_acc))
# Out:
# accuracy: 0.06293706293706294
